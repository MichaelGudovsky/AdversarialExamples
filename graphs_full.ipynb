# %%
import matplotlib.pyplot as plt

# %%
S2Nratio =[82.65, 72.95, 62.65, 52.65, 49.64, 47.88, 46.63, 45.66]

#Proposed_
Proposed_AlexNet=   [ 95.65, 95.38, 78.87, 03.63, 0.97, 0.25, 0.17, 0.13  ]
Proposed_GoogLeNet= [ 95.33, 95.10, 86.27, 21.48, 8.70, 1.85, 0.76, 0.35  ]
Proposed_ResNet=    [ 97.20, 97.12, 92.69, 50.09, 34.43, 14.69, 7.36, 3.02]
Proposed_VggNet=    [ 94.86, 94.69, 84.71, 14.53, 5.07, 1.33, 0.29, 0.15  ]


#Deep_Fool_
Deep_Fool_AlexNet=   [ 96.93, 96.92, 86.11, 54.43, 34.54, 19.43, 09.85, 04.59]
Deep_Fool_GoogLeNet= [ 96.71, 96.71, 90.74, 75.38, 62.26, 46.53, 30.76, 17.48]
Deep_Fool_ResNet=    [ 97.93, 97.93, 95.57, 87.34, 79.11, 68.83, 55.77, 40.65]
Deep_Fool_VggNet=    [ 96.31, 96.30, 90.44, 72.04, 54.16, 34.66, 18.34, 7.91 ] 
  

#Deep_Fool_and_rand_
Deep_Fool_and_rand_AlexNet=   [ 95.91, 95.91, 86.74, 31.46, 05.74, 01.92, 0.51, 0.31 ]
Deep_Fool_and_rand_GoogLeNet= [ 95.62, 95.62, 90.02, 59.18, 29.68, 15.78, 03.60, 1.12]
Deep_Fool_and_rand_ResNet=    [ 97.35, 97.34, 95.01, 78.34, 56.99, 42.25, 18.43, 7.42]
Deep_Fool_and_rand_VggNet=    [ 95.01, 95.00, 89.49, 52.81, 17.59, 07.16, 01.51, 0.61] 


#Deep_Fool_rand_bgd
Deep_Fool_rand_bgdAlexNet=   [ 95.93, 95.94, 87.72, 36.18, 06.92, 01.77, 0.62, 0.31  ]
Deep_Fool_rand_bgdGoogLeNet= [ 95.63, 95.62, 90.53, 62.36, 32.23, 14.87, 04.93, 0.97 ]
Deep_Fool_rand_bgdResNet=    [ 97.34, 97.34, 95.33, 80.43, 59.07, 40.86, 22.59, 06.56]
Deep_Fool_rand_bgdVggNet=    [ 95.94, 95.00, 90.12, 57.31, 20.23, 06.66, 02.01, 0.58 ]


#Naive Gaussian_Noise_
Gaussian_Noise_AlexNet=   [ 100, 100, 98.80, 92.06, 82.48, 73.27, 67.25, 59.26 ]
Gaussian_Noise_GoogLeNet= [ 100, 100, 98.57, 93.73, 88.36, 83.75, 80.73, 77.12 ]
Gaussian_Noise_ResNet=    [ 100, 100, 99.15, 96.27, 93.39, 90.98, 89.42, 87.37 ]
Gaussian_Noise_VggNet=    [ 100, 100, 98.49, 92.92, 87.13, 81.62, 77.91, 75.54 ]

# %%
# function that visualize the data use differnt line style for each method and different color for each network
def plot_data(x, y, label, linestyle, color):
    plt.plot(x, y, label=label, linestyle=linestyle, color=color, linewidth=2.0)

plt.figure(figsize=(20, 10))
# plot the data
plot_data(S2Nratio, Proposed_AlexNet, 'Proposed_AlexNet', linestyle='-', color='red')
plot_data(S2Nratio, Proposed_GoogLeNet, 'Proposed_GoogLeNet', linestyle='-', color='blue')
plot_data(S2Nratio, Proposed_ResNet, 'Proposed_ResNet', linestyle='-', color='green')
plot_data(S2Nratio, Proposed_VggNet, 'Proposed_VggNet', linestyle='-', color='black')

plot_data(S2Nratio, Deep_Fool_AlexNet, 'Deep_Fool_AlexNet', linestyle='--', color='red')
plot_data(S2Nratio, Deep_Fool_GoogLeNet, 'Deep_Fool_GoogLeNet', linestyle='--', color='blue')
plot_data(S2Nratio, Deep_Fool_ResNet, 'Deep_Fool_ResNet', linestyle='--', color='green')
plot_data(S2Nratio, Deep_Fool_VggNet, 'Deep_Fool_VggNet', linestyle='--', color='black')

plot_data(S2Nratio, Deep_Fool_and_rand_AlexNet, 'Deep_Fool_and_rand_AlexNet', linestyle='-.', color='red')
plot_data(S2Nratio, Deep_Fool_and_rand_GoogLeNet, 'Deep_Fool_and_rand_GoogLeNet', linestyle='-.', color='blue')
plot_data(S2Nratio, Deep_Fool_and_rand_ResNet, 'Deep_Fool_and_rand_ResNet', linestyle='-.', color='green')
plot_data(S2Nratio, Deep_Fool_and_rand_VggNet, 'Deep_Fool_and_rand_VggNet', linestyle='-.', color='black')

plot_data(S2Nratio, Deep_Fool_rand_bgdAlexNet, 'Deep_Fool_rand_bgdAlexNet', linestyle=':', color='red')
plot_data(S2Nratio, Deep_Fool_rand_bgdGoogLeNet, 'Deep_Fool_rand_bgdGoogLeNet', linestyle=':', color='blue')
plot_data(S2Nratio, Deep_Fool_rand_bgdResNet, 'Deep_Fool_rand_bgdResNet', linestyle=':', color='green')

plot_data(S2Nratio, Gaussian_Noise_AlexNet, 'Gaussian_Noise_AlexNet', linestyle='--', color='red')
plot_data(S2Nratio, Gaussian_Noise_GoogLeNet, 'Gaussian_Noise_GoogLeNet', linestyle='--', color='blue')
plot_data(S2Nratio, Gaussian_Noise_ResNet, 'Gaussian_Noise_ResNet', linestyle='--', color='green')
plot_data(S2Nratio, Gaussian_Noise_VggNet, 'Gaussian_Noise_VggNet', linestyle='--', color='black')

# set the title and legend and show the plot
plt.title('S2Nratio vs Accuracy')
plt.xlabel('S2Nratio')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# make a plot for each network with subplots for each method
plt.figure(figsize=(20, 10))
plt.subplot(2, 2, 1)
plot_data(S2Nratio, Proposed_AlexNet, 'CCUAP_AlexNet', linestyle='-', color='red')
plot_data(S2Nratio, Deep_Fool_AlexNet, 'ADFP_AlexNet', linestyle='--', color='red')
plot_data(S2Nratio, Deep_Fool_and_rand_AlexNet, 'ADFP_RT_AlexNet', linestyle='-.', color='red')
plot_data(S2Nratio, Deep_Fool_rand_bgdAlexNet, 'ADFP_RT_BI_AlexNet', linestyle=':', color='red')
plot_data(S2Nratio, Gaussian_Noise_AlexNet, 'Naive_Noise_AlexNet', linestyle=':', color='purple')


plt.title('SignaltoNoiseRatio vs Accuracy for AlexNet')
plt.xlabel('SNR[dB]')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 2)
plot_data(S2Nratio, Proposed_GoogLeNet, 'CCUAP_GoogLeNet', linestyle='-', color='blue')
plot_data(S2Nratio, Deep_Fool_GoogLeNet, 'ADFP_GoogLeNet', linestyle='--', color='blue')
plot_data(S2Nratio, Deep_Fool_and_rand_GoogLeNet, 'ADFP_RT_GoogLeNet', linestyle='-.', color='blue')
plot_data(S2Nratio, Deep_Fool_rand_bgdGoogLeNet, 'ADFP_RT_BI_GoogLeNet', linestyle=':', color='blue')
plot_data(S2Nratio, Gaussian_Noise_GoogLeNet, 'Naive_Noise_GoogLeNet', linestyle=':', color='purple')


plt.title('SignaltoNoiseRatio vs Accuracy for GoogLeNet')
plt.xlabel('SNR[dB]')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 3)
plot_data(S2Nratio, Proposed_ResNet, 'CCUAP_ResNet', linestyle='-', color='green')
plot_data(S2Nratio, Deep_Fool_ResNet, 'ADFP_ResNet', linestyle='--', color='green')
plot_data(S2Nratio, Deep_Fool_and_rand_ResNet, 'ADFP_RT_ResNet', linestyle='-.', color='green')
plot_data(S2Nratio, Deep_Fool_rand_bgdResNet, 'ADFP_RT_BI_ResNet', linestyle=':', color='green')
plot_data(S2Nratio, Gaussian_Noise_ResNet, 'Naive_Noise_ResNet', linestyle=':', color='purple')


plt.title('SignaltoNoiseRatio vs Accuracy for ResNet')
plt.xlabel('SNR[dB]')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 4)
plot_data(S2Nratio, Proposed_VggNet, 'CCUAP_VggNet', linestyle='-', color='black')
plot_data(S2Nratio, Deep_Fool_VggNet, 'ADFP_VggNet', linestyle='--', color='black')
plot_data(S2Nratio, Deep_Fool_and_rand_VggNet, 'ADFP_RT_VggNet', linestyle='-.', color='black')
plot_data(S2Nratio, Deep_Fool_rand_bgdVggNet, 'ADFP_RT_BI_VggNet', linestyle=':', color='black')
plot_data(S2Nratio, Gaussian_Noise_VggNet, 'Naive_Noise_VggNet', linestyle=':', color='purple')



plt.title('SignaltoNoiseRatio vs Accuracy for VggNet')
plt.xlabel('SNR[dB]')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# make a plot for each network with subplots for each method
plt.figure(figsize=(20, 10))
plt.subplot(2, 2, 1)
plot_data(S2Nratio, Proposed_AlexNet, 'CCUAP_AlexNet', linestyle='-', color='red')
plot_data(S2Nratio, Proposed_GoogLeNet, 'CCUAP_GoogLeNet', linestyle='--', color='red')
plot_data(S2Nratio, Proposed_ResNet, 'CCUAP_ResNet', linestyle='-.', color='red')
plot_data(S2Nratio, Proposed_VggNet, 'CCUAP_VggNet', linestyle=':', color='red')


plt.title('SNR vs Accuracy for CCUAP')
plt.xlabel('SNR[dB]')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 2)
plot_data(S2Nratio, Deep_Fool_AlexNet, ' ADFP_AlexNet', linestyle='-', color='blue')
plot_data(S2Nratio, Deep_Fool_GoogLeNet, 'ADFP_GoogLeNet', linestyle='--', color='blue')
plot_data(S2Nratio, Deep_Fool_ResNet, 'ADFP_ResNet', linestyle='-.', color='blue')
plot_data(S2Nratio, Deep_Fool_VggNet, 'ADFP_VggNet', linestyle=':', color='blue')


plt.title('SNR vs Accuracy for ADFP')
plt.xlabel('SNR[dB]')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 3)
plot_data(S2Nratio,  Deep_Fool_and_rand_AlexNet, ' ADFP_RT_AlexNet', linestyle='-', color='green')
plot_data(S2Nratio,  Deep_Fool_and_rand_GoogLeNet, 'ADFP_RT_GoogLeNet', linestyle='--', color='green')
plot_data(S2Nratio,  Deep_Fool_and_rand_ResNet, 'ADFP_RT_ResNet', linestyle='-.', color='green')
plot_data(S2Nratio,  Deep_Fool_and_rand_VggNet, 'ADFP_RT_VggNet', linestyle=':', color='green')

plt.title('SNR vs Accuracy for ADFP_RT')
plt.xlabel('SNR[dB]')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 4)
plot_data(S2Nratio, Deep_Fool_rand_bgdAlexNet, 'ADFP_RT_BI_AlexNet', linestyle='-', color='black')
plot_data(S2Nratio, Deep_Fool_rand_bgdGoogLeNet, 'ADFP_RT_BI_GoogLeNet', linestyle='--', color='black')
plot_data(S2Nratio, Deep_Fool_rand_bgdResNet, 'ADFP_RT_BI_ResNet', linestyle='-.', color='black')
plot_data(S2Nratio, Deep_Fool_rand_bgdVggNet, 'ADFP_RT_BI_VggNet', linestyle=':', color='black')


plt.title('SNR vs Accuracy for ADFP_RT_BI')
plt.xlabel('SNR[dB]')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
SSIM = [0.20, 0.25, 0.42, 0.46, 0.52, 0.60, 0.75, 0.83, 0.87, 1]  
our_method =                       [00.38, 01.44, 09.43, 22.89 ,31.19 ,52.39, 75.20, 86.08, 95.58, 100]
averaged_DF =                      [15.91, 51.35, 60.65, 86.38, 87.86, 95.12, 98.19, 98.49, 99.67, 100]
averaged_DF_with_rand =                 [09.68, 53.62, 85.53, 97.13, 98.38, 99.44, 99.97, 99.98, 99.99, 100]
averaged_DF_with_rand_and_background =  [00.56, 05.66, 16.38, 30.31, 40.24, 51.95, 76.70, 89.70, 97.98, 100]
naive_noise =                           [00.53, 02.07, 18.29, 27.93, 33.86, 67.62, 81.60, 95.24, 99.62, 100]

 #different methods on GoogleNet
our_method1 =                       [03.77, 12.93, 36.96, 42.31, 64.11, 70.52, 80.57, 91.62, 93.60, 100]
averaged_DF1 =                      [18.74, 51.27, 79.30, 94.55, 95.39, 96.24, 96.68, 98.71, 99.48, 100]
averaged_DF_with_rand1 =                 [13.67, 59.12, 83.73, 98.85, 98.94, 99.75, 99.97, 99.98, 99.99, 100]
averaged_DF_with_rand_and_background1 =  [04.21, 24.31, 37.27, 51.27, 67.46, 82.66, 91.42, 95.09, 99.99, 100]
naive_noise1 =                           [04.81, 17.26, 57.31, 63.95, 70.43, 82.60, 91.78, 95.07, 98.64, 100]

#different methods on VGG
our_method2 =                       [01.21, 05.68, 24.62, 36.90, 49.14, 61.00, 76.04, 91.34, 98.21, 100]
averaged_DF2 =                      [13.55, 73.57, 74.40, 81.84, 93.64, 94.71, 97.97, 98.85, 99.88, 100]
averaged_DF_with_rand2 =                 [02.16, 60.74, 81.35, 94.37, 97.16, 98.88, 99.94, 99.98, 99.99, 100]
averaged_DF_with_rand_and_background2 =  [02.01, 20.91, 42.18, 56.92, 77.09, 89.98, 94.72, 99.89, 99.96, 100]
naive_noise2 =                           [01.98, 08.00, 34.07, 61.29, 71.25, 85.81, 90.66, 95.63, 97.19, 100]
 #different methods on ResNet

our_method3 =                       [13.26, 32.37, 52.19, 60.98, 68.64, 77.71, 83.78, 89.18, 98.59, 100]
averaged_DF3 =                      [19.56, 77.31, 89.64, 97.56, 98.96, 98.97, 99.11, 99.51, 99.91, 100]
averaged_DF_with_rand3 =                 [15.35, 61.66, 86.44, 98.71, 99.89, 99.97, 99.98, 99.99, 99.99, 100]
averaged_DF_with_rand_and_background3 =  [14.11, 33.67, 42.59, 71.10, 79.74, 89.17, 95.82, 97.36, 99.98, 100]
naive_noise3 =                           [21.39, 40.00, 72.49, 78.05, 81.09, 89.34, 95.18, 96.99, 98.89, 100]

# %%
def plot_data(x, y, label, linestyle, color):
    plt.plot(x, y, label=label, linestyle=linestyle, color=color, linewidth=2.0)

plt.figure(figsize=(20, 10))

# %%
# make a plot for each network with subplots for each method
plt.figure(figsize=(20, 10))
plt.subplot(2, 2, 1)
plot_data(SSIM, our_method, 'CCUAP', linestyle='-', color='red')
plot_data(SSIM, averaged_DF, 'ADFP', linestyle='--', color='red')
plot_data(SSIM, averaged_DF_with_rand, 'ADFP_RT', linestyle='-.', color='red')
plot_data(SSIM, averaged_DF_with_rand_and_background, 'ADFP_RT_BI', linestyle=':', color='red')
plot_data(SSIM, naive_noise, 'Naive_Noise_AlexNet', linestyle=':', color='purple')


plt.title('Evaluation of different models on AlexNet')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()


plt.subplot(2, 2, 2)
plot_data(SSIM, our_method1, 'CCUAP', linestyle='-', color='blue')
plot_data(SSIM, averaged_DF1, 'ADFP', linestyle='--', color='blue')
plot_data(SSIM, averaged_DF_with_rand1, 'ADFP_RT', linestyle='-.', color='blue')
plot_data(SSIM, averaged_DF_with_rand_and_background1, 'ADFP_RT_BI', linestyle=':', color='blue')
plot_data(SSIM, naive_noise1, 'Naive_Noise_GoogLeNet', linestyle=':', color='purple')


plt.title('Evaluation of different models on GoogLeNet')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()


plt.subplot(2, 2, 3)
plot_data(SSIM, our_method2, 'CCUAP', linestyle='-', color='green')
plot_data(SSIM, averaged_DF2, 'ADFP', linestyle='--', color='green')
plot_data(SSIM, averaged_DF_with_rand2, 'ADFP_RT', linestyle='-.', color='green')
plot_data(SSIM, averaged_DF_with_rand_and_background2, 'ADFP_RT_BI', linestyle=':', color='green')
plot_data(SSIM, naive_noise2, 'Naive_Noise_ResNet', linestyle=':', color='purple')


plt.title('Evaluation of different models on VGG')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()


plt.subplot(2, 2, 4)
plot_data(SSIM, our_method3, 'CCUAP', linestyle='-', color='black')
plot_data(SSIM, averaged_DF3, 'ADFP', linestyle='--', color='black')
plot_data(SSIM, averaged_DF_with_rand3, 'ADFP_RT', linestyle='-.', color='black')
plot_data(SSIM, averaged_DF_with_rand_and_background3, 'ADFP_RT_BI', linestyle=':', color='black')
plot_data(SSIM, naive_noise3, 'Naive_Noise_VggNet', linestyle=':', color='purple')



plt.title('Evaluation of different models on ResNet')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()
plt.show()

# %%
#CCUAP
CCUAP_eval_AlexNet =      [00.38, 01.44, 09.43, 22.89 ,31.19 ,52.39, 75.20, 86.08, 95.58, 100]
CCUAP_eval_GoogLeNet =    [03.77, 12.93, 36.96, 42.31, 64.11, 70.52, 80.57, 91.62, 93.60, 100]
CCUAP_eval_ResNet =       [13.26, 32.37, 52.19, 60.98, 68.64, 77.71, 83.78, 89.18, 98.59, 100]
CCUAP_eval_VGG =          [01.21, 05.68, 24.62, 36.90, 49.14, 61.00, 76.04, 91.34, 98.21, 100]

#ADFP
ADFP_eval_AlexNet =      [15.91, 51.35, 60.65, 86.38, 87.86, 95.12, 98.19, 98.49, 99.67, 100]
ADFP_eval_GoogLeNet =    [18.74, 51.27, 79.30, 94.55, 95.39, 96.24, 96.68, 98.71, 99.48, 100]
ADFP_eval_ResNet =       [19.56, 77.31, 89.64, 97.56, 98.96, 98.97, 99.11, 99.51, 99.91, 100]
ADFP_eval_VGG =          [13.55, 73.57, 74.40, 81.84, 93.64, 94.71, 97.97, 98.85, 99.88, 100]

#ADFP_RT
ADFP_RT_eval_AlexNet =       [09.68, 53.62, 85.53, 97.13, 98.38, 99.44, 99.97, 99.98, 99.99, 100]
ADFP_RT_eval_GoogLeNet =     [13.67, 59.12, 83.73, 98.85, 98.94, 99.75, 99.97, 99.98, 99.99, 100]
ADFP_RT_eval_ResNet =        [15.35, 61.66, 86.44, 98.71, 99.89, 99.97, 99.98, 99.99, 99.99, 100]
ADFP_RT_eval_VGG =           [02.16, 60.74, 81.35, 94.37, 97.16, 98.88, 99.94, 99.98, 99.99, 100]

#ADFP_RT_BI
ADFP_RT_BI_eval_AlexNet =       [00.56, 05.66, 16.38, 30.31, 40.24, 51.95, 76.70, 89.70, 97.98, 100]
ADFP_RT_BI_eval_GoogLeNet =     [04.21, 24.31, 37.27, 51.27, 67.46, 82.66, 91.42, 95.09, 99.99, 100]
ADFP_RT_BI_eval_ResNet =        [12.11, 33.67, 42.59, 71.10, 79.74, 89.17, 95.82, 97.36, 99.98, 100]
ADFP_RT_BI_eval_VGG =           [02.01, 20.91, 42.18, 56.92, 77.09, 89.98, 94.72, 99.89, 99.96, 100]

#naive noise
eval_AlexNet =      [00.53, 02.07, 18.29, 27.93, 33.86, 57.62, 79.60, 87.24, 95.62, 100]
eval_GoogLeNet =    [04.81, 17.26, 57.31, 63.95, 70.43, 82.60, 91.78, 95.07, 98.64, 100]
eval_ResNet =       [21.39, 40.00, 72.49, 78.05, 81.09, 89.34, 95.18, 96.99, 98.89, 100]
eval_VGG =          [01.98, 08.00, 34.07, 61.29, 71.25, 85.81, 90.66, 95.63, 97.19, 100]

# %%
plt.figure(figsize=(20, 10))
plt.subplot(2, 3, 1)
plot_data(SSIM, CCUAP_eval_AlexNet, 'AlexNet', linestyle='-', color='blue')
plot_data(SSIM, CCUAP_eval_GoogLeNet, 'GoogLeNet', linestyle='--', color='red')
plot_data(SSIM, CCUAP_eval_ResNet, 'ResNet', linestyle='-.', color='green')
plot_data(SSIM, CCUAP_eval_VGG, 'VGG', linestyle=':', color='black')


plt.title('CCUAP different classifiers ')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()


plt.subplot(2, 3, 4)
plot_data(SSIM, ADFP_eval_AlexNet, 'AlexNet', linestyle='-', color='blue')
plot_data(SSIM, ADFP_eval_GoogLeNet, 'GoogLeNet', linestyle='--', color='red')
plot_data(SSIM, ADFP_eval_ResNet, 'ResNet', linestyle='-.', color='green')
plot_data(SSIM, ADFP_eval_VGG, 'VGG', linestyle=':', color='black')


plt.title('ADFP different on classifiers')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()


plt.subplot(2, 3, 5)
plot_data(SSIM, ADFP_RT_eval_AlexNet, 'AlexNet', linestyle='-', color='blue')
plot_data(SSIM, ADFP_RT_eval_GoogLeNet, 'GoogLeNet', linestyle='--', color='red')
plot_data(SSIM, ADFP_RT_eval_ResNet, 'ResNet', linestyle='-.', color='green')
plot_data(SSIM, ADFP_RT_eval_VGG, 'VGG', linestyle=':', color='black')


plt.title('ADFP_RT on different classifiers')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()


plt.subplot(2, 3, 6)
plot_data(SSIM, ADFP_RT_BI_eval_AlexNet, 'AlexNet', linestyle='-', color='blue')
plot_data(SSIM, ADFP_RT_BI_eval_GoogLeNet, 'GoogLeNet', linestyle='--', color='red')
plot_data(SSIM, ADFP_RT_BI_eval_ResNet, 'ResNet', linestyle='-.', color='green')
plot_data(SSIM, ADFP_RT_BI_eval_VGG, 'VGG', linestyle=':', color='black')


plt.title('ADFP_RT_BI on different classifiers')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()

plt.subplot(2, 3, 3)
plot_data(SSIM, eval_AlexNet, 'AlexNet', linestyle='-', color='blue')
plot_data(SSIM, eval_GoogLeNet, 'GoogLeNet', linestyle='--', color='red')
plot_data(SSIM, eval_ResNet, 'ResNet', linestyle='-.', color='green')
plot_data(SSIM, eval_VGG, 'VGG', linestyle=':', color='black')


plt.title('Naive Noise on different classifiers')
plt.xlabel('SSIM')
plt.ylabel('Accuracy [%]')
plt.legend()
plt.grid()
plt.show()
